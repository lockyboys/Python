# %% [markdown]
# # 2. 자료구조
#
# 자료구조는 **많은 양의 데이터를 체계적으로 다루는 방법**입니다.
# 파이썬에는 **여러 데이터를 효율적으로 관리**하는 4가지 주요 자료구조가 있습니다.
#
# | 자료구조 | 순서 | 변경 | 중복 | 표기법 | 활용 예시 |
# | --- | --- | --- | --- | --- | --- |
# | **리스트** | ⭕ | ⭕ | ⭕ | `[]` | 시간별 혈압기록, 처방순서 |
# | **튜플** | ⭕ | ❌ | ⭕ | `()` | 환자 기본정보, 좌표값 |
# | **딕셔너리** | 키-값 | ⭕ | 키 중복 ❌ | `{key: value}` | 환자정보, 진료기록 |
# | **집합** | ❌ | ⭕ | ❌ | `{}` | 중복 처방되면 안되는 약물 |

# %% [markdown]
# ## 📝 리스트

# %%
# 환자 혈압 기록 (시간순)
blood_pressures = [120, 125, 130, 118, 135, 128, 122]

# 처방약 목록
medications = ["아스피린", "메트포르민", "리시노프릴", "아토르바스타틴"]

# 환자 정보 (서로 다른 타입도 가능)
patient_infos = ["김환자", 65, True, 175.5]  # 이름, 나이, 고혈압여부, 키

# %%
# [직접해보기]
# 아래 정보를 리스트로 만들어보세요
# 체온 기록:
# 36.5, 36.8, 37.1, 38.0
# 환자 이름 목록:
# "김환자", "이환자", "박환자"

# 코드 작성
temperatures = [36.5, 36.8, 37.1, 38.0]
patient_names = ["김환자", "이환자", "박환자"]

print(f"체온 기록: {temperatures}")
print(f"환자 이름 목록: {patient_names}")
# Out:
# 체온 기록: [36.5, 36.8, 37.1, 38.0]
# 환자 이름 목록: ['김환자', '이환자', '박환자']

# %% [markdown]
# ### 인덱싱과 슬라이싱

# %% [markdown]
# #### 인덱싱
# 특정 위치의 데이터 가져오기

# %%
# 처방약 목록
medications = ["아스피린", "메트포르민", "리시노프릴", "아토르바스타틴", "오메프라졸"]

# %% [markdown]
# 특정 처방약만 확인하고 싶다면?

# %%
# 첫 번째 처방약
medications[0]
# Out:
# '아스피린'

# %%
# 두 번째 처방약
medications[1]
# Out:
# '메트포르민'

# %%
# 마지막 처방약 (저녁 마지막 복용약)
medications[-1]
# Out:
# '오메프라졸'

# %%
# 마지막에서 두 번째 처방약
medications[-2]
# Out:
# '아토르바스타틴'

# %% [markdown]
# #### 슬라이싱
# 여러 데이터를 범위로 가져오기
#
# **슬라이싱 문법**
#
# - `[시작:끝]`: 시작 인덱스부터 끝-1 인덱스까지
# - `[:끝]`: 처음부터 끝-1 인덱스까지
# - `[시작:]`: 시작부터 끝까지
# - `[:]`: 전체
# - `[시작:끝:간격]`: 시작부터 끝-1 인덱스까지 간격만큼 건너뛰기
# - `[::간격]`: 처음부터 끝까지 간격만큼 건너뛰기

# %%
medications = ["아스피린", "메트포르민", "리시노프릴", "아토르바스타틴", "오메프라졸"]

# %% [markdown]
# 연속된 여러개의 데이터를 한번에 지칭하고 싶다면?

# %%
# 처음부터 3개 (0, 1, 2번째)
medications[0:3]
# Out:
# ['아스피린', '메트포르민', '리시노프릴']

# %%
# 2번째부터 3번째까지 (2, 3번째)
medications[2:4]
# Out:
# ['리시노프릴', '아토르바스타틴']

# %%
# 처음부터 3개 (0, 1, 2번째)
medications[:3]
# Out:
# ['아스피린', '메트포르민', '리시노프릴']

# %%
# 처음부터 2번째까지 (0, 1, 2번째)
medications[:3]
# Out:
# ['아스피린', '메트포르민', '리시노프릴']

# %%
# 2번째부터 끝까지 (2, 3, 4번째)
medications[2:]
# Out:
# ['리시노프릴', '아토르바스타틴', '오메프라졸']

# %%
# 마지막 2개부터 끝까지 (3, 4번째)
medications[-2:]
# Out:
# ['아토르바스타틴', '오메프라졸']

# %%
# 전체
medications[:]
# Out:
# ['아스피린', '메트포르민', '리시노프릴', '아토르바스타틴', '오메프라졸']

# %%
# 짝수 인덱스만 (0, 2, 4번째)
medications[::2]
# Out:
# ['아스피린', '리시노프릴', '오메프라졸']

# %%
# 전체 역순
medications[::-1]
# Out:
# ['오메프라졸', '아토르바스타틴', '리시노프릴', '메트포르민', '아스피린']

# %%
# [직접해보기]
# 아래 리스트를 사용해서 슬라이싱해보세요
# temperatures = [36.5, 36.7, 37.0, 38.1, 37.8]
# 1. 앞의 3개 값 출력
# 2. 마지막 2개 값 출력
# 3. 전체 역순 출력

# 코드 작성
temperatures = [36.5, 36.7, 37.0, 38.1, 37.8]

# 1. 앞의 3개 값 출력
print(f"앞의 3개 값: {temperatures[:3]}")

# 2. 마지막 2개 값 출력
print(f"마지막 2개 값: {temperatures[-2:]}")

# 3. 전체 역순 출력
print(f"전체 역순: {temperatures[::-1]}")
# Out:
# 앞의 3개 값: [36.5, 36.7, 37.0]
# 마지막 2개 값: [38.1, 37.8]
# 전체 역순: [37.8, 38.1, 37.0, 36.7, 36.5]

# %%
# 문자열 슬라이싱

patient_name = "김철수"

print(patient_name[0:2])  # "김철"
print(patient_name[1:3])  # "철수"
print(patient_name[1:])  # "철수"
print(patient_name[:1])  # "김"
# Out:
# 김철
# 철수
# 철수
# 김

# %% [markdown]
# ### 🛠️ 리스트 조작하기

# %% [markdown]
# #### ➕ 리스트에 요소 추가하기
#
# | 메소드 | 설명 | 특징 |
# | --- | --- | --- |
# | `append()` | 리스트 끝에 **1개 요소** 추가 | 하나의 객체를 통째로 추가 |
# | `insert(위치, 값)` | **원하는 위치**에 1개 요소 추가 | 특정 인덱스에 삽입 가능 |
# | `extend()` | 리스트 끝에 **여러 요소** 한번에 추가 | 반복 가능한 객체의 각 요소를 개별 추가 |

# %%
# 환자의 혈압 측정 기록 관리
blood_pressures = [120, 125, 130, 118]
blood_pressures
# Out:
# [120, 125, 130, 118]

# %%
# append: 1개 데이터를 맨 끝에 추가
blood_pressures.append(135)
print(f"새 측정 후: {blood_pressures}")
# Out:
# 새 측정 후: [120, 125, 130, 118, 135]

# %%
# insert: 1개 데이터를 원하는 위치에 추가
blood_pressures.insert(1, 122)  # 인덱스 1 번째 위치에 추가
print(f"누락값 추가 후: {blood_pressures}")
# Out:
# 누락값 추가 후: [120, 122, 122, 125, 130, 118, 135]

# %%
# extend: 여러 데이터를 맨 끝에 추가
evening_readings = [128, 122, 119]
blood_pressures.extend(evening_readings)
print(f"저녁 측정값 추가 후: {blood_pressures}")
# Out:
# 저녁 측정값 추가 후: [120, 122, 122, 125, 130, 118, 135, 128, 122, 119]

# %%
# append vs extend 차이점
test_readings = [140, 145]
blood_pressures.append(test_readings)  # 리스트가 하나의 요소로 추가됨
print(f"append로 추가: {blood_pressures}")
# Out:
# append로 추가: [120, 122, 122, 125, 130, 118, 135, 128, 122, 119, [140, 145]]

# %%
# TODO : 리스트 추가 메서드 사용하기
temperatures = [36.5, 36.7, 37.0]

# 37.5 추가
temperatures.append(37.5)

# 인덱스 1 위치에 36.3 추가
temperatures.insert(1, 36.3)

# [38.0, 37.8] 추가
temperatures.extend([38.0, 37.8])

print(temperatures)
# Out:
# [36.5, 36.3, 36.7, 37.0, 37.5, 38.0, 37.8]

# %%
# [직접해보기]
# 아래 리스트에 값을 추가해보세요
# heart_rates = [72, 75, 78]
# 1. append()로 80 추가
# 2. insert()로 인덱스 1 위치에 70 추가
# 3. extend()로 [82, 85] 추가

# 코드 작성
heart_rates = [72, 75, 78]

# 1. append()로 80 추가
heart_rates.append(80)

# 2. insert()로 인덱스 1 위치에 70 추가
heart_rates.insert(1, 70)

# 3. extend()로 [82, 85] 추가
heart_rates.extend([82, 85])

print(heart_rates)
# Out:
# [72, 70, 75, 78, 80, 82, 85]

# %% [markdown]
# #### ➖ 리스트에서 요소 삭제하기
#
# | 메소드 | 설명 | 반환값 | 특징 |
# | --- | --- | --- | --- |
# | `remove(값)` | **값**으로 삭제 | 없음 | 첫 번째 일치하는 것만 삭제 |
# | `pop(인덱스)` | **인덱스**로 삭제 | 삭제된 값 반환 | 인덱스 생략 시 마지막 요소 |
# | `clear()` | **모든 요소** 삭제 | 없음 | 리스트가 빈 상태가 됨 |
# | `del` | **인덱스/슬라이스** 삭제 | 없음 | 변수 자체도 삭제 가능 |

# %%
# 처방약 목록 관리
medications = ["아스피린", "메트포르민", "임시처방약", "리시노프릴", "아토르바스타틴"]
medications
# Out:
# ['아스피린', '메트포르민', '임시처방약', '리시노프릴', '아토르바스타틴']

# %%
# remove: 값으로 삭제 (첫 번째 일치하는 것만 삭제)
medications.remove("임시처방약")
print(f"처방 제거 후: {medications}")
# Out:
# 처방 제거 후: ['아스피린', '메트포르민', '리시노프릴', '아토르바스타틴']

# %%
# pop: 특정 인덱스로 삭제하고 삭제된 값 반환
removed_med = medications.pop(1)  # 인덱스 1번째 약물 삭제
print(f"삭제된 약물: {removed_med}")
print(f"처방 제거 후: {medications}")
# Out:
# 삭제된 약물: 메트포르민
# 처방 제거 후: ['아스피린', '리시노프릴', '아토르바스타틴']

# %%
# 마지막 요소 삭제
last_med = medications.pop()
print(f"삭제된 약물: {last_med}")
print(f"처방 제거 후: {medications}")
# Out:
# 삭제된 약물: 아토르바스타틴
# 처방 제거 후: ['아스피린', '리시노프릴']

# %%
# clear: 리스트의 모든 요소 삭제 (모든 처방 중단)
medications.clear()
print(f"처방 제거 후: {medications}")
# Out:
# 처방 제거 후: []

# %%
# del: 변수 자체나 특정 인덱스 삭제
blood_pressures = [120, 125, 130, 118, 135, 128, 122]  # 혈압 측정값

del blood_pressures[0]    # 첫 번째 측정값 삭제
print(f"첫 측정값 제외: {blood_pressures}")

del blood_pressures[:2]   # 처음 2개 측정값 삭제
print(f"초기 측정값들 제외: {blood_pressures}")
# Out:
# 첫 측정값 제외: [125, 130, 118, 135, 128, 122]
# 초기 측정값들 제외: [118, 135, 128, 122]

# %%
del blood_pressures       # 변수 삭제
blood_pressures
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 del blood_pressures       # 변수 삭제
# ----> 2 blood_pressures
#
# NameError: name 'blood_pressures' is not defined

# %%
# TODO : 리스트 삭제 메서드 사용하기
oxygen_levels = [98, 97, 96, 95, 94]

# 값 96 삭제
oxygen_levels.remove(96)

# 마지막 값 삭제
oxygen_levels.pop()

print(oxygen_levels)

# 전체 삭제
oxygen_levels.clear()

print(oxygen_levels)
# Out:
# [98, 97, 95]
# []

# %%
# [직접해보기]
# 아래 리스트에서 값을 삭제해보세요
# symptoms = ["기침", "발열", "두통", "근육통"]
# 1. "두통" 삭제
# 2. 마지막 값 삭제
# 3. 전체 리스트 비우기

# 코드 작성
symptoms = ["기침", "발열", "두통", "근육통"]

# 1. "두통" 삭제
symptoms.remove("두통")
print(f"'두통' 삭제 후: {symptoms}")

# 2. 마지막 값 삭제
symptoms.pop()
print(f"마지막 값 삭제 후: {symptoms}")

# 3. 전체 리스트 비우기
symptoms.clear()
print(f"전체 리스트 비운 후: {symptoms}")
# Out:
# '두통' 삭제 후: ['기침', '발열', '근육통']
# 마지막 값 삭제 후: ['기침', '발열']
# 전체 리스트 비운 후: []

# %% [markdown]
# ### 🔍 유용한 리스트 메소드

# %% [markdown]
# #### 1. 정보 확인 메소드
#
# 리스트에 대한 정보를 얻는 메소드들입니다.
#
# | 메소드/연산자 | 설명 | 반환값 |
# | --- | --- | --- |
# | `len()` | 리스트 길이 반환 | 정수 |
# | `index(값)` | 특정 값의 위치 반환 | 정수 (인덱스) |
# | `count(값)` | 특정 값의 개수 반환 | 정수 |
# | `in` | 값 존재 여부 확인 | Boolean |

# %%
# 환자 이름 목록
patient_names = ['김철수', '이영희', '박민수', '이영희', '최지연']
patient_names
# Out:
# ['김철수', '이영희', '박민수', '이영희', '최지연']

# %%
# len(): 리스트 길이 반환
patient_count = len(patient_names)
print(f"총 환자 수: {patient_count}")
# Out:
# 총 환자 수: 5

# %%
# index(): 특정 값의 index위치 반환 (첫 번째로 나타나는 위치)
lee_position = patient_names.index('이영희')
print(f"이영희 환자 위치: {lee_position}")
# Out:
# 이영희 환자 위치: 1

# %%
# count(): 특정 값의 개수 반환
lee_count = patient_names.count('이영희')
print(f"이영희 동명이인 수: {lee_count}")
# Out:
# 이영희 동명이인 수: 2

# %%
# in 연산자: 값 존재 여부 확인 (True/False)
print(f"홍길동 환자 등록: {'홍길동' in patient_names}")
print(f"김철수 환자 등록: {'김철수' in patient_names}")
# Out:
# 홍길동 환자 등록: False
# 김철수 환자 등록: True

# %%
# TODO : 정보 확인 메소드 사용하기
temperatures = [36.5, 37.1, 38.0, 37.1, 36.8]

# 리스트 길이 출력
print(len(temperatures))

# 37.1 위치 출력
print(temperatures.index(37.1))

# 37.1 개수 출력
print(temperatures.count(37.1))

# 39.0 존재 여부 출력
print(39.0 in temperatures)
# Out:
# 5
# 1
# 2
# False

# %%
# [직접해보기]
# 아래 리스트를 사용해서 결과를 출력해보세요
# symptoms = ["기침", "발열", "기침", "두통"]
# 1. 전체 개수 출력
# 2. "기침" 개수 출력
# 3. "발열" 위치 출력
# 4. "근육통" 존재 여부 확인

# 코드 작성
symptoms = ["기침", "발열", "기침", "두통"]

# 1. 전체 개수 출력
print(f"전체 개수: {len(symptoms)}")

# 2. "기침" 개수 출력
print(f"'기침' 개수: {symptoms.count('기침')}")

# 3. "발열" 위치 출력
print(f"'발열' 위치: {symptoms.index('발열')}")

# 4. "근육통" 존재 여부 확인
print(f"'근육통' 존재 여부: {'근육통' in symptoms}")
# Out:
# 전체 개수: 4
# '기침' 개수: 2
# '발열' 위치: 1
# '근육통' 존재 여부: False

# %% [markdown]
# #### 2. 정렬 메소드
#
# 리스트의 순서를 변경하는 메소드들입니다.
#
# | 메소드 | 설명 | 원본 리스트 변경 여부 | 반환값 |
# | --- | --- | --- | --- |
# | `sorted()` | 새로운 정렬된 리스트 생성 | 변경 안됨 | 새로운 정렬된 리스트 |
# | `sort()` | 원본 리스트 자체를 정렬 | 변경됨 | 없음 (None) |
# | `reverse()` | 원본 리스트 순서를 뒤집기 | 변경됨 | 없음 (None) |

# %%
# 환자별 체중 데이터 분석
patient_weights = [65.5, 78.2, 52.1, 89.7, 71.3]
print(f"원본 체중 데이터: {patient_weights}")
# Out:
# 원본 체중 데이터: [65.5, 78.2, 52.1, 89.7, 71.3]

# %%
# sorted(): 새로운 정렬된 리스트 반환 (원본 유지)
sorted_weights = sorted(patient_weights)
print(f"원본 유지: {patient_weights}")
print(f"정렬된 체중: {sorted_weights}")
# Out:
# 원본 유지: [65.5, 78.2, 52.1, 89.7, 71.3]
# 정렬된 체중: [52.1, 65.5, 71.3, 78.2, 89.7]

# %%
# sort(): 원본 리스트 자체를 정렬
patient_weights.sort()
print(f"원본 정렬됨: {patient_weights}")
# Out:
# 원본 정렬됨: [52.1, 65.5, 71.3, 78.2, 89.7]

# %%
# reverse(): 리스트 순서를 뒤집기
patient_names = ["김철수", "이영희", "박민수", "최지연"]

patient_names.reverse()
print(f"뒤집어서 정렬: {patient_names}")
# Out:
# 뒤집어서 정렬: ['최지연', '박민수', '이영희', '김철수']

# %%
# 특별한 정렬 방법들

departments = ['소아과', '내과', '산부인과', '외과', '정형외과'] # 진료과 목록

by_length = sorted(departments, key=len)  # 길이순 정렬
print(f"길이순: {by_length}")

# 가나다순 정렬
sorted_departments = sorted(departments)
print(f"가나다순: {sorted_departments}")

# 역순 정렬 (ㅎ부터 ㄱ까지)
reverse_departments = sorted(departments, reverse=True)
print(f"내림차순: {reverse_departments}")
# Out:
# 길이순: ['내과', '외과', '소아과', '산부인과', '정형외과']
# 가나다순: ['내과', '산부인과', '소아과', '외과', '정형외과']
# 내림차순: ['정형외과', '외과', '소아과', '산부인과', '내과']

# %%
# TODO : 정렬 메소드 사용하기
blood_sugars = [140, 110, 180, 95, 130]

# 오름차순 정렬
print(sorted(blood_sugars))

# 원본 리스트 정렬
blood_sugars.sort()

print(blood_sugars)

# 리스트 뒤집기
blood_sugars.reverse()

print(blood_sugars)
# Out:
# [95, 110, 130, 140, 180]
# [95, 110, 130, 140, 180]
# [180, 140, 130, 110, 95]

# %%
# [직접해보기]
# 아래 리스트를 정렬해보세요
# heart_rates = [88, 72, 95, 68, 80]
# 1. 오름차순 정렬
# 2. 내림차순 정렬
# 3. 리스트 뒤집기

# 코드 작성
heart_rates = [88, 72, 95, 68, 80]

# 1. 오름차순 정렬
heart_rates.sort()
print(f"오름차순 정렬: {heart_rates}")

# 2. 내림차순 정렬
heart_rates.sort(reverse=True)
print(f"내림차순 정렬: {heart_rates}")

# 3. 리스트 뒤집기
heart_rates.reverse()
print(f"리스트 뒤집기: {heart_rates}")
# Out:
# 오름차순 정렬: [68, 72, 80, 88, 95]
# 내림차순 정렬: [95, 88, 80, 72, 68]
# 리스트 뒤집기: [68, 72, 80, 88, 95]

# %% [markdown]
# #### 3. 변환 메소드
#
# 리스트를 다른 형태로 변환하는 메소드입니다.

# %%
# 진료과 목록을 문자열로 변환
departments = ["내과", "외과", "소아과", "산부인과"]

# join(): 리스트를 문자열로 합치기
result1 = ", ".join(departments)
print(f"진료과 목록: {result1}")

result2 = " | ".join(departments)
print(f"진료과 구분: {result2}")

result3 = "".join(departments)
print(f"진료과 연결: {result3}")
# Out:
# 진료과 목록: 내과, 외과, 소아과, 산부인과
# 진료과 구분: 내과 | 외과 | 소아과 | 산부인과
# 진료과 연결: 내과외과소아과산부인과

# %%
# 숫자 리스트를 문자열로 합치기 (문자열로 변환 후 join)

# 혈압 수치를 문자열로 변환
systolic_pressures = [120, 125, 130, 135]
bp_string = ", ".join(map(str, systolic_pressures))
print(f"수축기 혈압 기록: {bp_string}")
# Out:
# 수축기 혈압 기록: 120, 125, 130, 135

# %%
# TODO : join() 사용하기
symptoms = ["기침", "발열", "두통"]

# 쉼표로 연결
result = ", ".join(symptoms)

print(result)

# / 로 연결
result2 = " / ".join(symptoms)

print(result2)
# Out:
# 기침, 발열, 두통
# 기침 / 발열 / 두통

# %%
# [직접해보기]
# 아래 리스트를 join()으로 연결해보세요
# medications = ["아스피린", "타이레놀", "메트포르민"]
# 1. ", " 로 연결
# 2. " / " 로 연결

# 코드 작성
medications = ["아스피린", "타이레놀", "메트포르민"]

# 1. ", " 로 연결
result1 = ", ".join(medications)
print(result1)

# 2. " / " 로 연결
result2 = " / ".join(medications)
print(result2)
# Out:
# 아스피린, 타이레놀, 메트포르민
# 아스피린 / 타이레놀 / 메트포르민

# %% [markdown]
# ### 🔗 리스트 연산

# %% [markdown]
# #### 리스트 연산자
#
# 두 개 이상의 리스트를 조합하는 방법들입니다.

# %%
# 리스트 합치기 (+)
morning_meds = ["아스피린", "메트포르민"]
afternoon_meds = ["인슐린", "혈압약"]
daily_meds = morning_meds + afternoon_meds
print(f"하루 처방: {daily_meds}")
# Out:
# 하루 처방: ['아스피린', '메트포르민', '인슐린', '혈압약']

# %%
# 리스트 반복 (*)
emergency_meds = ["에피네프린"]
emergency_stocks = emergency_meds * 3 # 응급약품 비상 준비 (3회분)
print(f"응급약품 재고: {emergency_stocks}")
# Out:
# 응급약품 재고: ['에피네프린', '에피네프린', '에피네프린']

# %%
# 복합 예제
icu_staffs = ["의사A", "간호사B"]
general_ward_staffs = icu_staffs * 2  # ICU 인력을 일반병동에 2배 배치
all_staffs = icu_staffs + general_ward_staffs + ["원장"]
print(f"전체 의료진: {all_staffs}")
print(f"총 의료진: {len(all_staffs)}명")
# Out:
# 전체 의료진: ['의사A', '간호사B', '의사A', '간호사B', '의사A', '간호사B', '원장']
# 총 의료진: 7명

# %%
# TODO : 리스트 연산하기
ward_a = ["환자A", "환자B"]
ward_b = ["환자C", "환자D"]

# 리스트 합치기
all_patients = ward_a + ward_b

print(all_patients)

# 리스트 반복하기
repeat_patients = ward_a * 2

print(repeat_patients)
# Out:
# ['환자A', '환자B', '환자C', '환자D']
# ['환자A', '환자B', '환자A', '환자B']

# %%
# [직접해보기]
# 아래 리스트를 사용해서 결과를 출력해보세요
# morning_patients = ["김환자", "이환자"]
# afternoon_patients = ["박환자", "최환자"]
# 1. 두 리스트 합치기
# 2. morning_patients를 3번 반복하기

# 코드 작성
morning_patients = ["김환자", "이환자"]
afternoon_patients = ["박환자", "최환자"]

# 1. 두 리스트 합치기
all_day_patients = morning_patients + afternoon_patients
print(f"하루 전체 환자: {all_day_patients}")

# 2. morning_patients를 3번 반복하기
repeated_morning_patients = morning_patients * 3
print(f"반복된 오전 환자: {repeated_morning_patients}")
# Out:
# 하루 전체 환자: ['김환자', '이환자', '박환자', '최환자']
# 반복된 오전 환자: ['김환자', '이환자', '김환자', '이환자', '김환자', '이환자']

# %% [markdown]
# ## 📦 튜플 - 변경되지 않는 리스트
#
# 튜플은 리스트와 같이 여러 개의 데이터를 순서대로 저장하지만 한 번 만들면 변경할 수 없는 자료구조입니다.

# %% [markdown]
# ### 튜플의 불변성 (Immutable)
# #### 불변성이란?
# 불변성(immutable)이란 **객체가 생성된 후 그 내용을 변경할 수 없는 성질**을 말합니다.
# ```python
# # 가변(mutable) vs 불변(immutable) 비교
# patient_list = ["김환자", "65세"]    # 리스트: 가변
# patient_tuple = ("김환자", "65세")   # 튜플: 불변
#
# # 리스트는 내용 변경 가능
# patient_list[1] = "66세"
# print(f"리스트 변경 후: {patient_list}")
#
# # 튜플은 내용 변경 불가능
# patient_tuple[1] = "66세"  # 에러 발생!
# ```
#
# 튜플은 **불변성(immutable)**을 가진 자료구조입니다.
# 즉, 한 번 생성된 후에는 내용을 변경할 수 없습니다.
#
#
# **왜 불변성이 중요한가?**
# - **데이터 안전성**: 실수로 중요한 정보(환자 ID, 생년월일 등)가 변경되는 것을 방지
# - **해시 가능**: 딕셔너리의 키로 사용 가능
# - **메모리 효율성**: 같은 내용의 튜플은 메모리를 공유할 수 있음
# ```python
# # 의료 정보에서 불변성 활용 예시
# HOSPITAL_LOCATION = (37.5665, 126.9780)  # 병원 위치 좌표 (변경되면 안 됨)
# EMERGENCY_CODE = ("119", "응급실", "24시간")  # 응급 연락처 (변경되면 안 됨)
#
# print(f"병원 위치: {HOSPITAL_LOCATION}")
# print(f"응급 연락처: {EMERGENCY_CODE}")
# ```

# %% [markdown]
# ### 튜플 사용하기

# %%
numbers = (1, 2, 3, 4, 5)
type(numbers)
# Out:
# tuple

# %%
# 괄호 씌우지 않으면 튜플
blood_types = "A", "B", "O", "AB"
print(f"혈액형: {blood_types}")
print(f"데이터 타입: {type(blood_types)}")
# Out:
# 혈액형: ('A', 'B', 'O', 'AB')
# 데이터 타입: <class 'tuple'>

# %%
# 데이터 읽기

print(f"첫 번째 혈액형: {blood_types[0]}")
print(f"마지막 혈액형: {blood_types[-1]}")
# Out:
# 첫 번째 혈액형: A
# 마지막 혈액형: AB

# %%
patient_infos = ("김환자", 65, "고혈압")

# 튜플 언패킹
name, age, diagnosis = patient_infos
print(f"{name}은 {age}살이고 {diagnosis} 진단을 받았습니다")
# Out:
# 김환자은 65살이고 고혈압 진단을 받았습니다

# %%
# 튜플은 변경 불가능
patient_infos[0] = "박환자"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2971948180.py in <cell line: 0>()
#       1 # 튜플은 변경 불가능
# ----> 2 patient_infos[0] = "박환자"
#
# TypeError: 'tuple' object does not support item assignment

# %%
# TODO : 튜플 만들기 및 언패킹
patient_info = ("김환자", 65, "고혈압")

# 튜플 언패킹
name, age, diagnosis = patient_info

print(name)
print(age)
print(diagnosis)
# Out:
# 김환자
# 65
# 고혈압

# %%
# [직접해보기]
# 아래 튜플을 만들어보세요
# 응급 연락처:
# "119", "응급실", "24시간"

# 코드 작성
emergency_contact = ("119", "응급실", "24시간")
print(f"응급 연락처: {emergency_contact}")
# Out:
# 응급 연락처: ('119', '응급실', '24시간')

# %%
# [직접해보기]
# 아래 튜플에서 값을 출력해보세요
# vital_signs = ("혈압", "맥박", "체온")
# 1. 첫 번째 값 출력
# 2. 마지막 값 출력

# 코드 작성
vital_signs = ("혈압", "맥박", "체온")

# 1. 첫 번째 값 출력
print(f"첫 번째 값: {vital_signs[0]}")

# 2. 마지막 값 출력
print(f"마지막 값: {vital_signs[-1]}")
# Out:
# 첫 번째 값: 혈압
# 마지막 값: 체온

# %%
# [직접해보기]
# 아래 튜플을 언패킹해보세요
# patient_data = ("이환자", 72, "당뇨")
# 변수:
# patient_name
# patient_age
# patient_diagnosis

# 코드 작성
patient_data = ("이환자", 72, "당뇨")

patient_name, patient_age, patient_diagnosis = patient_data

print(f"환자 이름: {patient_name}")
print(f"환자 나이: {patient_age}")
print(f"환자 진단명: {patient_diagnosis}")
# Out:
# 환자 이름: 이환자
# 환자 나이: 72
# 환자 진단명: 당뇨

# %% [markdown]
# ## 🗂️ 딕셔너리 - 이름표가 있는 상자
#
# 딕셔너리는 **`키(key)`와 `값(value)`의 쌍**으로 데이터를 저장하는 자료구조입니다. 마치 사전에서 단어(키)를 찾으면 뜻(값)이 나오는 것과 같습니다.

# %%
# 환자 정보 딕셔너리 만들기
patient = {
    "name": "김환자",           # str
    "age": 65,                 # int
    "diagnosis": "고혈압",      # str
    "medications": ["아스피린", "메트포르민"]  # list
}

# %%
patient["name"]
# Out:
# '김환자'

# %%
patient["age"]
# Out:
# 65

# %%
patient["phone"] # 없는 키값을 지정하면 키 에러
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3631803009.py in <cell line: 0>()
# ----> 1 patient["phone"] # 없는 키값을 지정하면 키 에러
#
# KeyError: 'phone'

# %%
# TODO : 딕셔너리 만들기
patient = {
    "name": "김환자",
    "age": 65,
    "diagnosis": "고혈압"
}

print(patient)
# Out:
# {'name': '김환자', 'age': 65, 'diagnosis': '고혈압'}

# %%
# [직접해보기]
# 아래 정보를 딕셔너리로 만들어보세요
# 이름: "이환자"
# 나이: 55
# 진단명: "당뇨"

# 코드 작성
patient_info = {
    "이름": "이환자",
    "나이": 55,
    "진단명": "당뇨"
}
print(patient_info)
# Out:
# {'이름': '이환자', '나이': 55, '진단명': '당뇨'}

# %% [markdown]
# ### 📝 딕셔너리 조작하기

# %% [markdown]
# #### ➕ 딕셔너리 추가 및 수정

# %%
# 초기 환자 정보
patient = {
    "name": "김환자",
    "age": 65,
    "diagnosis": "고혈압"
}

patient
# Out:
# {'name': '김환자', 'age': 65, 'diagnosis': '고혈압'}

# %%
# 새 정보 추가
patient["phone"] = "010-1234-5678"
patient["blood_type"] = "A형"
patient["doctor"] = "이의사"

# %%
# 정보 추가 후
patient
# Out:
# {'name': '김환자',
#  'age': 65,
#  'diagnosis': '고혈압',
#  'phone': '010-1234-5678',
#  'blood_type': 'A형',
#  'doctor': '이의사'}

# %%
# 정보 수정
patient["age"] = 66  # 나이 증가
patient["diagnosis"] = "고혈압, 당뇨"  # 추가 진단

# %%
# 정보 수정 후
patient
# Out:
# {'name': '김환자',
#  'age': 66,
#  'diagnosis': '고혈압, 당뇨',
#  'phone': '010-1234-5678',
#  'blood_type': 'A형',
#  'doctor': '이의사'}

# %%
# TODO : 딕셔너리 값 추가 및 수정
patient = {
    "name": "박환자",
    "age": 50
}

# diagnosis 추가
patient["diagnosis"] = "골절"

# 나이 수정
patient["age"] = 51

print(patient)
# Out:
# {'name': '박환자', 'age': 51, 'diagnosis': '골절'}

# %%
# [직접해보기]
# 아래 정보를 patient에 추가해보세요
# 키: 175.5
# 몸무게: 70

# 코드 작성
patient = {
    "name": "이환자",
    "age": 55,
    "diagnosis": "당뇨"
}

patient["키"] = 175.5
patient["몸무게"] = 70

print(patient)
# Out:
# {'name': '이환자', 'age': 55, 'diagnosis': '당뇨', '키': 175.5, '몸무게': 70}

# %% [markdown]
# #### ➖ 딕셔너리 삭제
# | 메소드 | 설명 | 반환값 | 특징 |
# | --- | --- | --- | --- |
# | `pop(키)` | **특정 키** 삭제 | 삭제된 값 반환 | 키가 없으면 기본값 반환 가능 |
# | `popitem()` | **마지막 키-값 쌍** 삭제 | (키, 값) 튜플 반환 | 딕셔너리가 비어있으면 KeyError |
# | `clear()` | **모든 키-값 쌍** 삭제 | 없음 | 빈 딕셔너리가 됨 |
# | `del` | **특정 키** 또는 **변수 자체** 삭제 | 없음 | 슬라이싱 불가 |

# %%
# 초기 환자 정보
patient = {
    "name": "김환자",
    "age": 65,
    "diagnosis": "고혈압",
    "phone": "010-1234-5678",
    "blood_type": "A형"
}
patient
# Out:
# {'name': '김환자',
#  'age': 65,
#  'diagnosis': '고혈압',
#  'phone': '010-1234-5678',
#  'blood_type': 'A형'}

# %%
# pop(): 특정 키 삭제하고 값 반환
removed_phone = patient.pop("phone")
print(f"삭제된 전화번호: {removed_phone}")
print("전화번호 삭제 후:", patient)
# Out:
# 삭제된 전화번호: 010-1234-5678
# 전화번호 삭제 후: {'name': '김환자', 'age': 65, 'diagnosis': '고혈압', 'blood_type': 'A형'}

# %%
# pop() 기본값 설정 (키가 없을 때)
email = patient.pop("email", "이메일 정보 없음")
print(f"이메일: {email}")

print("현재 환자 정보:", patient)
# Out:
# 이메일: 이메일 정보 없음
# 현재 환자 정보: {'name': '김환자', 'age': 65, 'diagnosis': '고혈압', 'blood_type': 'A형'}

# %%
# popitem(): 마지막 키-값 쌍 삭제
last_item = patient.popitem() # 키-값 튜플로 반환
print(f"마지막 삭제 항목: {last_item}")
print("마지막 항목 삭제 후:", patient)
# Out:
# 마지막 삭제 항목: ('blood_type', 'A형')
# 마지막 항목 삭제 후: {'name': '김환자', 'age': 65, 'diagnosis': '고혈압'}

# %%
# clear(): 모든 요소 삭제
patient.clear()
print("폐기 후 정보:", patient)
# Out:
# 폐기 후 정보: {}

# %%
# del: 특정 키나 변수 자체 삭제
patient = {"name": "박환자", "age": 45, "diagnosis": "감기"}

del patient["diagnosis"]  # 완치되어 진단명 삭제
print("삭제 후:", patient)
# Out:
# 삭제 후: {'name': '박환자', 'age': 45}

# %%
del patient # 변수 삭제

patient
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2143722791.py in <cell line: 0>()
#       1 del patient # 변수 삭제
#       2
# ----> 3 patient
#
# NameError: name 'patient' is not defined

# %%
# TODO : 딕셔너리 삭제하기
patient = {
    "name": "최환자",
    "age": 60,
    "phone": "010-1111-2222"
}
# phone 삭제
patient.pop("phone")

# age 삭제
del patient["age"]

print(patient)
# Out:
# {'name': '최환자'}

# %%
# [직접해보기]
# 아래 딕셔너리에서 값을 삭제해보세요
# patient = {
#     "name": "이환자",
#     "age": 70,
#     "diagnosis": "폐렴"
# }
# 1. diagnosis 삭제
# 2. age 삭제

# 코드 작성
patient = {
    "name": "이환자",
    "age": 70,
    "diagnosis": "폐렴"
}

# 1. diagnosis 삭제
del patient["diagnosis"]

# 2. age 삭제
patient.pop("age")

print(patient)
# Out:
# {'name': '이환자'}

# %% [markdown]
# ### 🔍 딕셔너리 정보 확인

# %%
# 환자 정보
patient = {"name": "이환자", "age": 55, "diagnosis": "당뇨", "doctor": "김의사"}
patient
# Out:
# {'name': '이환자', 'age': 55, 'diagnosis': '당뇨', 'doctor': '김의사'}

# %%
# keys(): 모든 키 확인
print("정보 항목들:", patient.keys())
# Out:
# 정보 항목들: dict_keys(['name', 'age', 'diagnosis', 'doctor'])

# %%
# values(): 모든 값 확인
print("정보 값들:", patient.values())
# Out:
# 정보 값들: dict_values(['이환자', 55, '당뇨', '김의사'])

# %%
# items(): 모든 키-값 쌍 확인
print("전체 정보:", patient.items())
# Out:
# 전체 정보: dict_items([('name', '이환자'), ('age', 55), ('diagnosis', '당뇨'), ('doctor', '김의사')])

# %%
# TODO : 딕셔너리 정보 확인하기
hospital = {
    "name": "서울병원",
    "beds": 300,
    "location": "서울"

}
print(hospital.keys())
print(hospital.values())
print(hospital.items())
# Out:
# dict_keys(['name', 'beds', 'location'])
# dict_values(['서울병원', 300, '서울'])
# dict_items([('name', '서울병원'), ('beds', 300), ('location', '서울')])

# %%
# [직접해보기]
# 아래 딕셔너리의 keys(), values(), items()를 출력해보세요
# medical_costs = {
#     "진료비": 15000,
#     "검사비": 25000
# }

# 코드 작성
medical_costs = {
    "진료비": 15000,
    "검사비": 25000
}

print(medical_costs.keys())
print(medical_costs.values())
print(medical_costs.items())
# Out:
# dict_keys(['진료비', '검사비'])
# dict_values([15000, 25000])
# dict_items([('진료비', 15000), ('검사비', 25000)])

# %% [markdown]
# ### 🔍 딕셔너리 안전한 접근
# - get()메소드
# - in 연산자

# %% [markdown]
# | 접근 방법 | 키가 없을 때 | 반환값 | 사용 시점 |
# | --- | --- | --- | --- |
# | `dict[키]` | KeyError 발생 | 해당 값 | 키가 확실히 존재할 때 |
# | `dict.get(키)` | None 반환 | 해당 값 또는 None | 안전한 접근이 필요할 때 |
# | `dict.get(키, 기본값)` | 기본값 반환 | 해당 값 또는 기본값 | 기본값을 설정하고 싶을 때 |
# | `키 in dict` | False 반환 | True/False | 키 존재 여부만 확인할 때 |

# %% [markdown]
# #### get() 메소드

# %%
# 병원 진료비 정보
medical_costs = {
    "진료비": 15000,
    "검사비": 25000,
    "처방비": 8000,
    "입원비": 50000
}
medical_costs
# Out:
# {'진료비': 15000, '검사비': 25000, '처방비': 8000, '입원비': 50000}

# %%
# 안전한 방법 (키가 없을경우 None 반환)
mri_cost = medical_costs.get("MRI비용")
print("MRI 비용:", mri_cost)
# Out:
# MRI 비용: None

# %%
# 안전한 방법 (키가 없을경우 기본값 반환)
surgery_cost = medical_costs.get("MRI비용", "해당 없음")
print("MRI비용:", surgery_cost)
# Out:
# MRI비용: 해당 없음

# %%
# 직접 접근 시 에러 발생
print(medical_costs["MRI비용"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-919479904.py in <cell line: 0>()
#       1 # 직접 접근 시 에러 발생
# ----> 2 print(medical_costs["MRI비용"])
#
# KeyError: 'MRI비용'

# %%
# [직접해보기]
# 아래 딕셔너리에서 get()을 사용해보세요
# patient = {
#     "name": "김환자",
#     "age": 65
# }
# 1. "name" 가져오기
# 2. "phone" 가져오기 (기본값: "정보 없음")

# 코드 작성
patient = {
    "name": "김환자",
    "age": 65
}

# 1. "name" 가져오기
patient_name = patient.get("name")
print(f"환자 이름: {patient_name}")

# 2. "phone" 가져오기 (기본값: "정보 없음")
patient_phone = patient.get("phone", "정보 없음")
print(f"환자 전화번호: {patient_phone}")
# Out:
# 환자 이름: 김환자
# 환자 전화번호: 정보 없음

# %% [markdown]
# #### in 연산자
# in 연산자는 bool타입을 반환 합니다

# %%
medical_costs = {
    "진료비": 15000,
    "검사비": 25000,
    "처방비": 8000
}

medical_costs
# Out:
# {'진료비': 15000, '검사비': 25000, '처방비': 8000}

# %%
# 1. 키 존재 확인
print("진료비 항목 있음:", "진료비" in medical_costs)
print("수술비 항목 있음:", "수술비" in medical_costs)
# Out:
# 진료비 항목 있음: True
# 수술비 항목 있음: False

# %%
# 명시적으로 작성
print("진료비 항목 있음:", "진료비" in medical_costs.keys())
print("수술비 항목 있음:", "수술비" in medical_costs.keys())
# Out:
# 진료비 항목 있음: True
# 수술비 항목 있음: False

# %%
# 안전한 접근을 위한 조건문
if "수술비" in medical_costs:
    print(f"수술비: {medical_costs['수술비']}원")
else:
    print("수술비 정보가 없습니다")
# Out:
# 수술비 정보가 없습니다

# %%
# 2. 값 존재 확인
print("15000원 비용 있음:", 15000 in medical_costs.values())
print("100000원 비용 있음:", 100000 in medical_costs.values())
# Out:
# 15000원 비용 있음: True
# 100000원 비용 있음: False

# %%
medical_costs.items()
# Out:
# dict_items([('진료비', 15000), ('검사비', 25000), ('처방비', 8000)])

# %%
# 3. 키-값 쌍 존재 확인
print("(진료비, 15000) 쌍 존재:", ("진료비", 15000) in medical_costs.items())
print("(진료비, 20000) 쌍 존재:", ("진료비", 20000) in medical_costs.items())
# Out:
# (진료비, 15000) 쌍 존재: True
# (진료비, 20000) 쌍 존재: False

# %%
# 활용 예시
cost_type = "물리치료비"
if cost_type in medical_costs:
    print(f"{cost_type}: {medical_costs[cost_type]}원")
else:
    print(f"{cost_type} 정보가 없습니다")
# Out:
# 물리치료비 정보가 없습니다

# %%
# TODO : in 연산자 사용하기
patient = {
    "name": "정환자",
    "age": 40
}

print("name" in patient)
print("phone" in patient)
# Out:
# True
# False

# %%
# [직접해보기]
# 아래 조건을 확인해보세요
# patient = {
#     "name": "박환자",
#     "diagnosis": "감기"
# }
# 1. "name" 키 존재 여부
# 2. "phone" 키 존재 여부

# 코드 작성
patient = {
    "name": "박환자",
    "diagnosis": "감기"
}

# 1. "name" 키 존재 여부
print(f"'name' 키 존재 여부: {'name' in patient}")

# 2. "phone" 키 존재 여부
print(f"'phone' 키 존재 여부: {'phone' in patient}")

# %% [markdown]
# ## 🎯 집합 - 중복 없는 데이터
#
# 집합(set)은 **중복을 허용하지 않으며 순서가 없는** 자료구조입니다. 수학의 집합 개념과 동일합니다.

# %%
# 환자 알레르기 약물 리스트 (중복 포함)
allergy_drugs_list = ["페니실린", "아스피린", "페니실린", "이부프로펜", "아스피린"]
print(f'알레르기 약물 리스트: {allergy_drugs_list}')
print(f'약물 개수: {len(allergy_drugs_list)}')
# Out:
# 알레르기 약물 리스트: ['페니실린', '아스피린', '페니실린', '이부프로펜', '아스피린']
# 약물 개수: 5

# %%
# 집합 만들기 (중복 자동 제거)
allergy_drugs_set = {"페니실린", "아스피린", "페니실린", "이부프로펜", "아스피린"}
print(f'알레르기 약물 집합: {allergy_drugs_set}')
print(f'고유 약물 개수: {len(allergy_drugs_set)}')
# Out:
# 알레르기 약물 집합: {'이부프로펜', '아스피린', '페니실린'}
# 고유 약물 개수: 3

# %%
# 리스트를 집합으로 변환 (중복 제거)
symptoms_list = ["발열", "기침", "발열", "두통", "기침", "오한"]  # 중복된 증상들
symptoms_set = set(symptoms_list)
print(f'고유 증상들: {symptoms_set}')  # 순서가 없기 때문에 출력 순서가 다를 수 있음
# Out:
# 고유 증상들: {'기침', '두통', '오한', '발열'}

# %%
# 다시 리스트로 변환
unique_symptoms = list(symptoms_set)
print(f'고유 증상 리스트: {unique_symptoms}')
# Out:
# 고유 증상 리스트: ['기침', '두통', '오한', '발열']

# %%
# TODO : 집합 만들기
medications = ["아스피린", "타이레놀", "아스피린", "인슐린"]

# 집합으로 변환
unique_meds = set(medications)

print(unique_meds)

# 리스트로 변환
unique_meds_list = list(unique_meds)

print(unique_meds_list)
# Out:
# {'타이레놀', '인슐린', '아스피린'}
# ['타이레놀', '인슐린', '아스피린']

# %%
# [직접해보기]
# 아래 리스트의 중복을 제거해보세요
# temperatures = [36.5, 36.5, 37.1, 38.0, 37.1]
# 1. set으로 변환
# 2. 다시 list로 변환

# 코드 작성
temperatures = [36.5, 36.5, 37.1, 38.0, 37.1]

# 1. set으로 변환
unique_temperatures_set = set(temperatures)
print(f"Set으로 변환: {unique_temperatures_set}")

# 2. 다시 list로 변환
unique_temperatures_list = list(unique_temperatures_set)
print(f"List로 변환: {unique_temperatures_list}")
# Out:
# Set으로 변환: {36.5, 37.1, 38.0}
# List로 변환: [36.5, 37.1, 38.0]

# %% [markdown]
# ### 🛠️ 집합 메소드

# %% [markdown]
# #### ➕ 집합에 요소 추가하기
#
# | 메소드 | 설명 | 특징 |
# | --- | --- | --- |
# | `add()` | **1개 요소** 추가 | 중복된 값은 추가되지 않음 |
# | `update()` | **여러 요소** 한번에 추가 | 반복 가능한 객체를 받아 각 요소를 개별 추가 |

# %%
allergy_drugs = {"페니실린", "아스피린", "설파제", "이부프로펜"}
print(f'기존 알레르기 약물: {allergy_drugs}')
# Out:
# 기존 알레르기 약물: {'이부프로펜', '아스피린', '설파제', '페니실린'}
# 추가 후: {'이부프로펜', '아목시실린', '설파제', '페니실린', '아스피린'}

# %%
# 새로운 알레르기 약물 한개 추가
allergy_drugs.add("아목시실린")
print(f'추가 후: {allergy_drugs}')
# Out:
# 추가 후: {'이부프로펜', '아목시실린', '설파제', '페니실린', '아스피린'}

# %%
# 여러 알레르기 약물을 한번에 추가
new_allergies = {"세팔렉신", "독시사이클린"}
allergy_drugs.update(new_allergies)
print(f'추가 약물들 등록 후: {allergy_drugs}')
# Out:
# 추가 약물들 등록 후: {'이부프로펜', '독시사이클린', '아목시실린', '설파제', '페니실린', '아스피린', '세팔렉신'}

# %%
# TODO : 집합 요소 추가하기
blood_types = {"A형", "B형"}

# "O형" 추가
blood_types.add("O형")

# {"AB형"} 추가
blood_types.update({"AB형"})

print(blood_types)
# Out:
# {'A형', 'O형', 'AB형', 'B형'}

# %%
# [직접해보기]
# 아래 집합에 값을 추가해보세요
# symptoms = {"발열", "기침"}
# 1. add()로 "두통" 추가
# 2. update()로 {"오한", "근육통"} 추가

# 코드 작성
symptoms = {"발열", "기침"}

# 1. add()로 "두통" 추가
symptoms.add("두통")

# 2. update()로 {"오한", "근육통"} 추가
symptoms.update({"오한", "근육통"})

print(symptoms)
# Out:
# {'발열', '두통', '기침', '근육통', '오한'}

# %% [markdown]
# #### ➖ 집합에서 요소 삭제하기
#
# | 메소드 | 설명 | 없는 요소 삭제 시 |
# | --- | --- | --- |
# | `remove()` | **1개 요소** 삭제 | KeyError 발생 |
# | `discard()` | **1개 요소** 삭제 | 에러 없이 무시 |

# %%
allergy_drugs = {"페니실린", "아스피린", "설파제", "이부프로펜", "아목시실린"}
allergy_drugs
# Out:
# {'설파제', '아목시실린', '아스피린', '이부프로펜', '페니실린'}

# %%
# 악물 제거
allergy_drugs.remove("설파제")
print(f'설파제 제거 후: {allergy_drugs}')
# Out:
# 설파제 제거 후: {'이부프로펜', '아목시실린', '페니실린', '아스피린'}

# %%
allergy_drugs.remove("설파제")  # 이미 제거된 약물
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-4133337865.py in <cell line: 0>()
# ----> 1 allergy_drugs.remove("설파제")  # 이미 제거된 약물
#
# KeyError: '설파제'

# %%
# 안전한 제거 방법 (존재하지 않아도 수행)
allergy_drugs.discard("설파제")  # 에러 없이 무시됨
allergy_drugs.discard("메트포르민")  # 원래 없던 약물도 에러 없음
print(f'제거 후: {allergy_drugs}')
# Out:
# 제거 후: {'이부프로펜', '아목시실린', '페니실린', '아스피린'}

# %%
# TODO : 집합 요소 삭제하기
departments = {"내과", "외과", "소아과"}

# "외과" 삭제
departments.remove("외과")

# "피부과" 안전 삭제
departments.discard("피부과")

print(departments)
# Out:
# {'내과', '소아과'}

# %%
# [직접해보기]
# 아래 집합에서 값을 삭제해보세요
# medications = {"아스피린", "타이레놀", "인슐린"}
# 1. remove()로 "타이레놀" 삭제
# 2. discard()로 "감기약" 삭제

# 코드 작성
medications = {"아스피린", "타이레놀", "인슐린"}

# 1. remove()로 "타이레놀" 삭제
medications.remove("타이레놀")

# 2. discard()로 "감기약" 삭제
medications.discard("감기약")

print(medications)
# Out:
# {'인슐린', '아스피린'}

# %% [markdown]
# ### 🔄 집합 연산
#
# 집합 연산은 **두 집합 사이의 관계**를 계산하는 방법입니다.
#
# - **연산자** (`|`, `&`, , `^`): 새로운 집합 반환
# - **메소드** (`.union()`, `.intersection()` 등): 새로운 집합 반환
# - **업데이트 메소드** (`.update()`, `.intersection_update()` 등): 원본 집합 변경

# %%
# 두 환자의 복용 약물 비교
patient_a_drugs = {"아스피린", "메트포르민", "리시노프릴", "심바스타틴"}
patient_b_drugs = {"아토르바스타틴", "메트포르민", "암로디핀", "심바스타틴"}

# %% [markdown]
# #### 1) 합집합 (Union) - 두 집합의 모든 요소

# %%
# 두 환자가 복용하는 모든 약물 종류

# 방법1: 연산자 활용
all_drugs_operator = patient_a_drugs | patient_b_drugs
print(f'전체 약물 (연산자): {all_drugs_operator}')

# 방법2: 메서드 활용
all_drugs_method = patient_a_drugs.union(patient_b_drugs)
print(f'전체 약물 (메서드): {all_drugs_method}')
# Out:
# 전체 약물 (연산자): {'메트포르민', '아토르바스타틴', '아스피린', '심바스타틴', '리시노프릴', '암로디핀'}
# 전체 약물 (메서드): {'메트포르민', '아토르바스타틴', '아스피린', '심바스타틴', '리시노프릴', '암로디핀'}

# %% [markdown]
# #### 2) 교집합 (Intersection) - 두 집합의 공통 요소

# %%
# 두 환자가 공통으로 복용하는 약물

# 방법1: 연산자 활용
common_drugs_operator = patient_a_drugs & patient_b_drugs
print(f'공통 복용약물 (연산자): {common_drugs_operator}')

# 방법2: 메서드 활용
common_drugs_method = patient_a_drugs.intersection(patient_b_drugs)
print(f'공통 복용약물 (메서드): {common_drugs_method}')
# Out:
# 공통 복용약물 (연산자): {'심바스타틴', '메트포르민'}
# 공통 복용약물 (메서드): {'심바스타틴', '메트포르민'}

# %% [markdown]
# #### 3) 차집합 (Difference) - 첫 번째 집합에만 있는 요소

# %%
# 환자 A만 복용하는 약물 (환자 B는 복용하지 않는 약물)

# 방법1: 연산자 활용
only_a_drugs_operator = patient_a_drugs - patient_b_drugs
print(f'환자 A 전용약물 (연산자): {only_a_drugs_operator}')

# 방법2: 메서드 활용
only_a_drugs_method = patient_a_drugs.difference(patient_b_drugs)
print(f'환자 A 전용약물 (메서드): {only_a_drugs_method}')
# Out:
# 환자 A 전용약물 (연산자): {'아스피린', '리시노프릴'}
# 환자 A 전용약물 (메서드): {'아스피린', '리시노프릴'}

# %% [markdown]
# #### 4) 대칭차집합 (Symmetric Difference) - 둘 중 하나에만 있는 요소

# %%
# 한 환자만 복용하는 약물들 (공통이 아닌 약물들)

# 방법1: 연산자 활용
unique_drugs_operator = patient_a_drugs ^ patient_b_drugs
print(f'각자만 복용하는 약물 (연산자): {unique_drugs_operator}')

# 방법2: 메서드 활용
unique_drugs_method = patient_a_drugs.symmetric_difference(patient_b_drugs)
print(f'각자만 복용하는 약물 (메서드): {unique_drugs_method}')
# Out:
# 각자만 복용하는 약물 (연산자): {'아토르바스타틴', '아스피린', '리시노프릴', '암로디핀'}
# 각자만 복용하는 약물 (메서드): {'아토르바스타틴', '아스피린', '리시노프릴', '암로디핀'}

# %%
# [직접해보기]
# 아래 집합을 사용해서 연산해보세요
# patient_a = {"감기", "고혈압", "당뇨"}
# patient_b = {"당뇨", "폐렴"}
# 1. 합집합
# 2. 교집합
# 3. 차집합
# 4. 대칭차집합

# 코드 작성
patient_a = {"감기", "고혈압", "당뇨"}
patient_b = {"당뇨", "폐렴"}

# 1. 합집합
print(f"합집합: {patient_a | patient_b}")

# 2. 교집합
print(f"교집합: {patient_a & patient_b}")

# 3. 차집합
print(f"차집합 (patient_a - patient_b): {patient_a - patient_b}")

# 4. 대칭차집합
print(f"대칭차집합: {patient_a ^ patient_b}")
# Out:
# 합집합: {'고혈압', '폐렴', '당뇨', '감기'}
# 교집합: {'당뇨'}
# 차집합 (patient_a - patient_b): {'감기', '고혈압'}
# 대칭차집합: {'감기', '고혈압', '폐렴'}

# %% [markdown]
# #### 원본 집합 업데이트 (In-place 연산)
#
# 원본 집합 자체를 변경하는 메소드들입니다.

# %%
# 합집합 업데이트 - 환자 A의 처방에 환자 B의 약물 추가
patient_a_drugs = {"아스피린", "메트포르민", "리시노프릴", "심바스타틴"}
patient_b_drugs = {"아토르바스타틴", "메트포르민", "암로디핀", "심바스타틴"}

print(f'업데이트 전 환자 A: {patient_a_drugs}')
patient_a_drugs.update(patient_b_drugs)
print(f'합집합 업데이트 후: {patient_a_drugs}')
# Out:
# 업데이트 전 환자 A: {'아스피린', '심바스타틴', '메트포르민', '리시노프릴'}
# 합집합 업데이트 후: {'메트포르민', '아토르바스타틴', '아스피린', '심바스타틴', '리시노프릴', '암로디핀'}

# %%
# 교집합 업데이트 - 공통 약물만 남기기
patient_a_drugs = {"아스피린", "메트포르민", "리시노프릴", "심바스타틴"}
patient_b_drugs = {"아토르바스타틴", "메트포르민", "암로디핀", "심바스타틴"}

print(f'교집합 업데이트 전: {patient_a_drugs}')
patient_a_drugs.intersection_update(patient_b_drugs)
print(f'교집합 업데이트 후: {patient_a_drugs}')
# Out:
# 교집합 업데이트 전: {'아스피린', '심바스타틴', '메트포르민', '리시노프릴'}
# 교집합 업데이트 후: {'심바스타틴', '메트포르민'}

# %%
# 차집합 업데이트 - 환자 A만의 고유 약물만 남기기
patient_a_drugs = {"아스피린", "메트포르민", "리시노프릴", "심바스타틴"}
patient_b_drugs = {"아토르바스타틴", "메트포르민", "암로디핀", "심바스타틴"}

print(f'차집합 업데이트 전: {patient_a_drugs}')
patient_a_drugs.difference_update(patient_b_drugs)
print(f'차집합 업데이트 후: {patient_a_drugs}')
# Out:
# 차집합 업데이트 전: {'아스피린', '심바스타틴', '메트포르민', '리시노프릴'}
# 차집합 업데이트 후: {'아스피린', '리시노프릴'}

# %%
# 대칭차집합 업데이트 - 공통이 아닌 약물들만 남기기
patient_a_drugs = {"아스피린", "메트포르민", "리시노프릴", "심바스타틴"}
patient_b_drugs = {"아토르바스타틴", "메트포르민", "암로디핀", "심바스타틴"}

print(f'대칭차집합 업데이트 전: {patient_a_drugs}')
patient_a_drugs.symmetric_difference_update(patient_b_drugs)
print(f'대칭차집합 업데이트 후: {patient_a_drugs}')
# Out:
# 대칭차집합 업데이트 전: {'아스피린', '심바스타틴', '메트포르민', '리시노프릴'}
# 대칭차집합 업데이트 후: {'아토르바스타틴', '아스피린', '리시노프릴', '암로디핀'}

# %% [markdown]
# ## 🔄 자료구조 변환과 내장 함수

# %% [markdown]
# ### 자료구조 변환
#
# 각 자료구조는 전용 함수를 사용해 생성하거나 다른 자료구조로부터 변환할 수 있습니다.

# %%
# 1. list() - 리스트로 변환
patient_ages_tuple = (65, 45, 32, 28, 55)
patient_ages_list = list(patient_ages_tuple)
print(f"튜플 → 리스트: {patient_ages_list}")
# Out:
# 튜플 → 리스트: [65, 45, 32, 28, 55]

# %%
# 문자열을 리스트로 변환
patient_id = "P001"
id_chars = list(patient_id)
print(f"문자열 → 리스트: {id_chars}")
# Out:
# 문자열 → 리스트: ['P', '0', '0', '1']

# %%
# [직접해보기]
# 아래 튜플과 문자열을 리스트로 변환해보세요
# blood_types = ("A", "B", "O", "AB")
# patient_code = "H001"

# 코드 작성
blood_types = ("A", "B", "O", "AB")
patient_code = "H001"

blood_types_list = list(blood_types)
patient_code_list = list(patient_code)

print(f"튜플을 리스트로 변환: {blood_types_list}")
print(f"문자열을 리스트로 변환: {patient_code_list}")
# Out:
# 튜플을 리스트로 변환: ['A', 'B', 'O', 'AB']
# 문자열을 리스트로 변환: ['H', '0', '0', '1']

# %%
# 2. tuple() - 튜플로 변환
departments = ["내과", "외과", "소아과"]
departments_tuple = tuple(departments)
print(f"리스트 → 튜플: {departments_tuple}")
# Out:
# 리스트 → 튜플: ('내과', '외과', '소아과')

# %%
# [직접해보기]
# 아래 리스트를 튜플로 변환해보세요
# symptoms = ["발열", "기침", "두통"]

# 코드 작성
symptoms = ["발열", "기침", "두통"]
symptoms_tuple = tuple(symptoms)
print(f"리스트를 튜플로 변환: {symptoms_tuple}")
# Out:
# 리스트를 튜플로 변환: ('발열', '기침', '두통')

# %%
# 3. dict() - 딕셔너리로 변환
# 키-값 쌍의 리스트로부터 딕셔너리 생성
patient_data = [("name", "김환자"), ("age", 65), ("department", "내과")]
patient_dict = dict(patient_data)
print(f"리스트 → 딕셔너리: {patient_dict}")
# Out:
# 리스트 → 딕셔너리: {'name': '김환자', 'age': 65, 'department': '내과'}

# %%
# [직접해보기]
# 아래 데이터를 딕셔너리로 변환해보세요
# cost_data = [
#     ("진료비", 15000),
#     ("검사비", 25000)
# ]

# 코드 작성
cost_data = [
    ("진료비", 15000),
    ("검사비", 25000)
]

cost_dict = dict(cost_data)
print(f"리스트를 딕셔너리로 변환: {cost_dict}")
# Out:
# 리스트를 딕셔너리로 변환: {'진료비': 15000, '검사비': 25000}

# %%
# 4. set() - 집합으로 변환
symptoms_list = ["발열", "기침", "발열", "두통", "기침"]
unique_symptoms = set(symptoms_list)
print(f"리스트 → 집합 (중복 제거): {unique_symptoms}")
# Out:
# 리스트 → 집합 (중복 제거): {'기침', '두통', '발열'}

# %%
# 리스트에서 중복 제거 팁
symptoms_list = ["발열", "기침", "발열", "두통", "기침"]
unique_symptoms_list = list(set(symptoms_list))
print(f"중복 제거된 리스트: {unique_symptoms_list}")
# Out:
# 중복 제거된 리스트: ['기침', '두통', '발열']

# %%
# [직접해보기]
# 아래 리스트의 중복을 제거해보세요
# medications = ["아스피린", "아스피린", "타이레놀", "인슐린"]

# 코드 작성
medications = ["아스피린", "아스피린", "타이레놀", "인슐린"]

# 1. 리스트를 set으로 변환하여 중복 제거
unique_medications_set = set(medications)
print(f"Set으로 변환 (중복 제거): {unique_medications_set}")

# 2. 다시 리스트로 변환
unique_medications_list = list(unique_medications_set)
print(f"List로 변환: {unique_medications_list}")
# Out:
# Set으로 변환 (중복 제거): {'타이레놀', '인슐린', '아스피린'}
# List로 변환: ['타이레놀', '인슐린', '아스피린']

# %% [markdown]
# ### 내장 함수 활용

# %% [markdown]
# #### 1. len() - 길이/개수 확인

# %%
patients = ["김환자", "이환자", "박환자"]
patient_info = {"name": "최환자", "age": 40, "department": "피부과"}
patient_ages = (65, 45, 32)
unique_symptoms = {"발열", "기침", "두통"}

print(f"환자 명단 길이: {len(patients)}")
print(f"환자 정보 항목 수: {len(patient_info)}")
print(f"나이 데이터 개수: {len(patient_ages)}")
print(f"고유 증상 수: {len(unique_symptoms)}")
# Out:
# 환자 명단 길이: 3
# 환자 정보 항목 수: 3
# 나이 데이터 개수: 3
# 고유 증상 수: 3

# %%
# [직접해보기]
# 아래 자료구조의 길이를 출력해보세요
# departments = ["내과", "외과", "소아과", "정형외과"]
# patient = {"name": "김환자", "age": 65}

# 코드 작성
departments = ["내과", "외과", "소아과", "정형외과"]
patient = {"name": "김환자", "age": 65}

print(f"departments 리스트의 길이: {len(departments)}")
print(f"patient 딕셔너리의 길이: {len(patient)}")
# Out:
# departments 리스트의 길이: 4
# patient 딕셔너리의 길이: 2

# %% [markdown]
# #### 2. sum() - 합계 계산

# %%
# 환자 나이 합계
patient_ages = [65, 45, 32, 28, 55]
total_age = sum(patient_ages)
average_age = sum(patient_ages) / len(patient_ages)

print(f"환자 나이 합계: {total_age}세")
print(f"평균 나이: {average_age:.1f}세")

# 진료과별 환자 수 합계
department_counts = [25, 18, 32, 15, 28]
total_patients = sum(department_counts)
print(f"전체 환자 수: {total_patients}명")
# Out:
# 환자 나이 합계: 225세
# 평균 나이: 45.0세
# 전체 환자 수: 118명

# %%
# [직접해보기]
# 아래 혈압 리스트의 합계와 평균을 구해보세요
# blood_pressures = [120, 130, 125, 140]

# 코드 작성
blood_pressures = [120, 130, 125, 140]

total_blood_pressure = sum(blood_pressures)
average_blood_pressure = total_blood_pressure / len(blood_pressures)

print(f"혈압 합계: {total_blood_pressure}")
print(f"혈압 평균: {average_blood_pressure}")
# Out:
# 혈압 합계: 515
# 혈압 평균: 128.75

# %% [markdown]
# #### 3. max(), min() - 최댓값, 최솟값

# %%
patient_ages = [65, 45, 32, 28, 55]
blood_pressures = [120, 135, 110, 145, 125]

print(f"최고령 환자 나이: {max(patient_ages)}세")
print(f"최연소 환자 나이: {min(patient_ages)}세")

print("=" * 30)

print(f"최고 혈압: {max(blood_pressures)}mmHg")
print(f"최저 혈압: {min(blood_pressures)}mmHg")
# Out:
# 최고령 환자 나이: 65세
# 최연소 환자 나이: 28세
# ...
# 최고 혈압: 145mmHg
# 최저 혈압: 110mmHg

# %%
# [직접해보기]
# 아래 체온 리스트에서 최고 체온과 최저 체온을 출력해보세요
# temperatures = [36.5, 37.2, 38.1, 36.9]

# 코드 작성
temperatures = [36.5, 37.2, 38.1, 36.9]

max_temp = max(temperatures)
min_temp = min(temperatures)

print(f"최고 체온: {max_temp}")
print(f"최저 체온: {min_temp}")
# Out:
# 최고 체온: 38.1
# 최저 체온: 36.5

# %% [markdown]
# #### 4. all(), any() - 논리 검사

# %%
# 모든 환자가 입원 중인지 확인
admission_status = [True, True, True, False]
all_admitted = all(admission_status)
any_admitted = any(admission_status)

print(f"모든 환자 입원 중: {all_admitted}")
print(f"입원 환자 존재: {any_admitted}")
# Out:
# 모든 환자 입원 중: False
# 입원 환자 존재: True

# %%
# 모든 환자가 성인인지 확인
patient_ages = [65, 45, 32, 28, 55]
all_adults = all(age >= 18 for age in patient_ages)
print(f"모든 환자가 성인: {all_adults}")

# 고혈압 환자가 있는지 확인
blood_pressures = [120, 135, 110, 145, 125]
has_hypertension = any(bp >= 140 for bp in blood_pressures)
print(f"고혈압 환자 존재: {has_hypertension}")
# Out:
# 모든 환자가 성인: True
# 고혈압 환자 존재: True

# %%
# [직접해보기]
# 아래 데이터를 사용해서 확인해보세요
# fever_status = [False, False, True]
# 1. 모두 발열이 있는지 확인
# 2. 한 명이라도 발열이 있는지 확인

# 코드 작성
fever_status = [False, False, True]

# 1. 모두 발열이 있는지 확인
all_fever = all(fever_status)
print(f"모두 발열이 있는지 확인: {all_fever}")

# 2. 한 명이라도 발열이 있는지 확인
any_fever = any(fever_status)
print(f"한 명이라도 발열이 있는지 확인: {any_fever}")
# Out:
# 모두 발열이 있는지 확인: False
# 한 명이라도 발열이 있는지 확인: True
